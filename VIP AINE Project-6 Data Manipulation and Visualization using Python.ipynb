# %% [markdown]
# ## Virtual Internship Program @ AINE.AI Project-6 submitted by Amit Purswani

# %% [markdown]
# ## Data Manipulation and Visualization using Python

# %%
## Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## Example of importing CSV data from a URL
medals_url = 'http://winterolympicsmedals.com/medals.csv'
medals = pd.read_csv(medals_url)

# %%
## Check if the data was properly imported into a dataframe
medals.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
## Example of importing Excel data from a URL
rbrte_data_url = 'https://www.eia.gov/dnav/pet/hist_xls/RBRTEd.xls'
rbrte = pd.read_excel(rbrte_data_url,sheet_name='Data 1',skiprows=2)

# %%
## Check if the data was properly imported into a dataframe
rbrte.head()
# Out:
#         Date  Europe Brent Spot Price FOB (Dollars per Barrel)
# 0 1987-05-20                                             18.63
# 1 1987-05-21                                             18.45
# 2 1987-05-22                                             18.55
# 3 1987-05-25                                             18.60
# 4 1987-05-26                                             18.63

# %%
## Importing necessary data-sets for this project
brics = pd.read_csv('D:\\Amit\\AINE\\project6\\data\\brics.csv')
cars = pd.read_csv('D:\\Amit\\AINE\\project6\\data\\cars.csv')
marks = pd.read_csv('D:\\Amit\\AINE\\project6\\data\\marks.csv')
mtcars = pd.read_csv('D:\\Amit\AINE\\project6\\data\\mtcars.csv')

# %% [markdown]
# ## 1. BRICS Dataset

# %%
## Check if all data was imported properly in dataframes
## BRICS
brics.head()
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
## Check if all data was imported properly in dataframes
## CARS
cars.head()
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True

# %%
## Check if all data was imported properly in dataframes
## MARKS
marks.head()
# Out:
#   Student_ID Student_Name    English      Maths    Science    History  \
# 0        S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1        S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2        S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3        S04        David  21.160844  95.052971  35.860852  62.865185
# 4        S05       Edward  63.250994  60.693247   7.020915  60.505272
#
#    Social_Studies
# 0       61.373070
# 1       80.805730
# 2       58.057612
# 3       95.264572
# 4       34.041671

# %%
## Check if all data was imported properly in dataframes
## MTCARS
mtcars.head()
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
## Display BRICS dataframe without print()
brics
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
## Display BRICS dataframe without print()
print(brics)
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# #### The difference is: without print - it comes in a certain format, whereas with print() just the data is displayed without any formatting.

# %%
## Checking the data-type
type(brics)
# Out:
# pandas.core.frame.DataFrame

# %%
## Exploring dataframe with few basic methods
## Head
brics.head()
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
## Shape of dataframe
brics.shape
# Out:
# (5, 5)

# %%
## Describe - some statistics regarding numeric data
brics.describe()
# Out:
#         population          area
# count     5.000000  5.000000e+00
# mean    601.600000  7.943919e+06
# std     644.806405  6.199591e+06
# min      55.000000  1.221037e+06
# 25%     144.000000  3.287590e+06
# 50%     200.000000  8.515767e+06
# 75%    1252.000000  9.596961e+06
# max    1357.000000  1.709824e+07

# %%
## Info about columns,rows, data-types, null-values
brics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        5 non-null      object
#  1   country     5 non-null      object
#  2   population  5 non-null      int64
#  3   area        5 non-null      int64
#  4   capital     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 328.0+ bytes

# %%
## Use Value Counts
brics['code'].value_counts()
# Out:
# SA    1
# RU    1
# BR    1
# IN    1
# CH    1
# Name: code, dtype: int64

# %%
## Sort by 'code' using sort_values()
brics.sort_values(by=['code'])
## by default Ascending is True
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %%
## Sort by 'code' using sort_values(), in descending order
brics.sort_values(by=['code'],ascending=False)
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 0   BR        Brazil         200   8515767   Brasilia

# %%
## Check the original dataframe
brics
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# #### Sorting didn't change the original data-frame.

# %%
## Find country with largest population
brics.sort_values(by=['population'],ascending=False)
# Out:
#   code       country  population      area    capital
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# #### The country with largest population is China.

# %%
## Find Country with smallest size
brics.sort_values(by=['area'])
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 1   RU        Russia         144  17098242     Moscow

# %% [markdown]
# #### South Africa is smallest in terms of size.

# %%
## Sorting a single column country
brics.country.sort_values(ascending=False)
# Out:
# 4    South Africa
# 1          Russia
# 2           India
# 3           China
# 0          Brazil
# Name: country, dtype: object

# %%
## Sort and print area column on from largest to smallest.
brics['area'].sort_values(ascending=False)
# Out:
# 1    17098242
# 3     9596961
# 0     8515767
# 2     3287590
# 4     1221037
# Name: area, dtype: int64

# %%
## Print area column from brics dataframe
brics['area']
# Out:
# 0     8515767
# 1    17098242
# 2     3287590
# 3     9596961
# 4     1221037
# Name: area, dtype: int64

# %%
## Print code column from the dataframe using dot
brics.code
# Out:
# 0    BR
# 1    RU
# 2    IN
# 3    CH
# 4    SA
# Name: code, dtype: object

# %%
### Print country, capital and population
brics[['country','capital', 'population']]
# Out:
#         country    capital  population
# 0        Brazil   Brasilia         200
# 1        Russia     Moscow         144
# 2         India  New Delhi        1252
# 3         China    Beijing        1357
# 4  South Africa   Pretoria          55

# %%
## Code Trial
df = pd.DataFrame({'name': ['Niko', 'Penelope', 'Aria'], 'average score': [10, 5, 3], 'max': [99, 100, 3]})

# %%
#df.average score

# %%
df['average score']
# Out:
# 0    10
# 1     5
# 2     3
# Name: average score, dtype: int64

# %%
brics
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
## Changing Index column
brics = pd.read_csv('D:\\Amit\\AINE\\project6\\data\\brics.csv',index_col=0)

# %%
brics
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %%
brics.loc['SA']
# Out:
# country       South Africa
# population              55
# area               1221037
# capital           Pretoria
# Name: SA, dtype: object

# %%
## Adding a new column
brics['on_earth']=[True,True,True,True,True]

# %%
brics
# Out:
#            country  population      area    capital  on_earth
# code
# BR          Brazil         200   8515767   Brasilia      True
# RU          Russia         144  17098242     Moscow      True
# IN           India        1252   3287590  New Delhi      True
# CH           China        1357   9596961    Beijing      True
# SA    South Africa          55   1221037   Pretoria      True

# %%
## Adding a new calculated column
brics['density'] = brics['population'] / brics['area'] * 1000000 #per sq.km

# %%
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
brics.style.set_precision(2)
# Out:
# <style  type="text/css" >
# </style><table id="T_4a193e06_f919_11eb_9aed_98e7434d3b95" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >population</th>        <th class="col_heading level0 col2" >area</th>        <th class="col_heading level0 col3" >capital</th>        <th class="col_heading level0 col4" >on_earth</th>        <th class="col_heading level0 col5" >density</th>    </tr>    <tr>        <th class="index_name level0" >code</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a193e06_f919_11eb_9aed_98e7434d3b95level0_row0" class="row_heading level0 row0" >BR</th>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row0_col0" class="data row0 col0" >Brazil</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row0_col1" class="data row0 col1" >200</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row0_col2" class="data row0 col2" >8515767</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row0_col3" class="data row0 col3" >Brasilia</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row0_col4" class="data row0 col4" >True</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row0_col5" class="data row0 col5" >23.49</td>
#             </tr>
#             <tr>
#                         <th id="T_4a193e06_f919_11eb_9aed_98e7434d3b95level0_row1" class="row_heading level0 row1" >RU</th>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row1_col0" class="data row1 col0" >Russia</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row1_col1" class="data row1 col1" >144</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row1_col2" class="data row1 col2" >17098242</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row1_col3" class="data row1 col3" >Moscow</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row1_col4" class="data row1 col4" >True</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row1_col5" class="data row1 col5" >8.42</td>
#             </tr>
#             <tr>
#                         <th id="T_4a193e06_f919_11eb_9aed_98e7434d3b95level0_row2" class="row_heading level0 row2" >IN</th>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row2_col0" class="data row2 col0" >India</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row2_col1" class="data row2 col1" >1252</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row2_col2" class="data row2 col2" >3287590</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row2_col3" class="data row2 col3" >New Delhi</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row2_col4" class="data row2 col4" >True</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row2_col5" class="data row2 col5" >380.83</td>
#             </tr>
#             <tr>
#                         <th id="T_4a193e06_f919_11eb_9aed_98e7434d3b95level0_row3" class="row_heading level0 row3" >CH</th>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row3_col0" class="data row3 col0" >China</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row3_col1" class="data row3 col1" >1357</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row3_col2" class="data row3 col2" >9596961</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row3_col3" class="data row3 col3" >Beijing</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row3_col4" class="data row3 col4" >True</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row3_col5" class="data row3 col5" >141.40</td>
#             </tr>
#             <tr>
#                         <th id="T_4a193e06_f919_11eb_9aed_98e7434d3b95level0_row4" class="row_heading level0 row4" >SA</th>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row4_col0" class="data row4 col0" >South Africa</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row4_col1" class="data row4 col1" >55</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row4_col2" class="data row4 col2" >1221037</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row4_col3" class="data row4 col3" >Pretoria</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row4_col4" class="data row4 col4" >True</td>
#                         <td id="T_4a193e06_f919_11eb_9aed_98e7434d3b95row4_col5" class="data row4 col5" >45.04</td>
#             </tr>
#     </tbody></table>

# %%
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
brics['density'].round(2)
# Out:
# code
# BR     23.49
# RU      8.42
# IN    380.83
# CH    141.40
# SA     45.04
# Name: density, dtype: float64

# %%
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
brics.loc['SA']
# Out:
# country       South Africa
# population              55
# area               1221037
# capital           Pretoria
# on_earth              True
# density            45.0437
# Name: SA, dtype: object

# %%
## Use .loc to print the values from all columns for IN
brics.loc['IN']
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %%
## Use .iloc to print the values from all columns from 3rd row (index number will be 1 less than the row number)
brics.iloc[2]
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %%
#ading a new ROW using append
newrow = {'code':'WK', 'country':'Wakanda', 'population':5,'area':1000000,'capital':'Wakanda City','on_earth':False,'density':5}
brics1 = brics.append(newrow,ignore_index=True)   # Ignoring the existing index.
# Ignoring the existing index will result into new dataframe index 0,1,2,....

# %%
brics1
# Out:
#         country  population      area       capital  on_earth     density code
# 0        Brazil         200   8515767      Brasilia      True   23.485847  NaN
# 1        Russia         144  17098242        Moscow      True    8.421918  NaN
# 2         India        1252   3287590     New Delhi      True  380.826076  NaN
# 3         China        1357   9596961       Beijing      True  141.398928  NaN
# 4  South Africa          55   1221037      Pretoria      True   45.043680  NaN
# 5       Wakanda           5   1000000  Wakanda City     False    5.000000   WK

# %%
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
#Adding a new row using .loc
brics.loc['WK'] = ['Wakanda', 5, 1000000, 'Wakanda City', False, 5]   
# Sequence is very important. Data types may get changed due to wrong sequence.
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000

# %%
## Add a new row in the dataframe using .loc any other country with some values in all columns.
brics.loc['UT'] = ['Utopia', 10, 200000, 'Edna', False, 10]

# %%
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# UT          Utopia          10    200000          Edna     False   10.000000

# %%
## Fetching data using two values
brics.loc["IN","capital"]
# Out:
# 'New Delhi'

# %%
## Fetching data using two values
brics["capital"].loc["IN"]
# Out:
# 'New Delhi'

# %%
## Fetching data using two values
brics.loc["IN"]['capital']
# Out:
# 'New Delhi'

# %%
brics1 = brics
brics1
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# UT          Utopia          10    200000          Edna     False   10.000000

# %%
## Drop column 'area' use axis=1
brics1.drop(['area'], axis=1)
# Out:
#            country  population       capital  on_earth     density
# code
# BR          Brazil         200      Brasilia      True   23.485847
# RU          Russia         144        Moscow      True    8.421918
# IN           India        1252     New Delhi      True  380.826076
# CH           China        1357       Beijing      True  141.398928
# SA    South Africa          55      Pretoria      True   45.043680
# WK         Wakanda           5  Wakanda City     False    5.000000
# UT          Utopia          10          Edna     False   10.000000

# %%
## Try deleting area and density columns from brics1 dataframe
brics1 = brics
brics1.drop(['area', 'density'], axis=1)
# Out:
#            country  population       capital  on_earth
# code
# BR          Brazil         200      Brasilia      True
# RU          Russia         144        Moscow      True
# IN           India        1252     New Delhi      True
# CH           China        1357       Beijing      True
# SA    South Africa          55      Pretoria      True
# WK         Wakanda           5  Wakanda City     False
# UT          Utopia          10          Edna     False

# %%
## Delete the record for Wakanda by using its index WK
# Hint: Use WK as identifier and delete axis argument or put axis = 0
brics1.drop(['WK'], axis=0)
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680
# UT          Utopia          10    200000       Edna     False   10.000000

# %%
brics1 = brics
# Another way to drop columns
brics1.drop(columns=['area', 'density'])
# Out:
#            country  population       capital  on_earth
# code
# BR          Brazil         200      Brasilia      True
# RU          Russia         144        Moscow      True
# IN           India        1252     New Delhi      True
# CH           China        1357       Beijing      True
# SA    South Africa          55      Pretoria      True
# WK         Wakanda           5  Wakanda City     False
# UT          Utopia          10          Edna     False

# %%
brics1 = brics
# Drop rows by index
brics1.drop(['IN', 'CH'])
# Out:
#            country  population      area       capital  on_earth    density
# code
# BR          Brazil         200   8515767      Brasilia      True  23.485847
# RU          Russia         144  17098242        Moscow      True   8.421918
# SA    South Africa          55   1221037      Pretoria      True  45.043680
# WK         Wakanda           5   1000000  Wakanda City     False   5.000000
# UT          Utopia          10    200000          Edna     False  10.000000

# %%
# Using shape function
for index in range(brics.shape[0]):    
    countryName = brics.iloc[index,0]  # row - index, column - 0
    cityName = brics.iloc[index, 3]  # row - index, column - 3
    print('The Capital City of', countryName, 'is', cityName)
# Out:
# The Capital City of Brazil is Brasilia
# The Capital City of Russia is Moscow
# The Capital City of India is New Delhi
# The Capital City of China is Beijing
# The Capital City of South Africa is Pretoria
# The Capital City of Wakanda is Wakanda City
# The Capital City of Utopia is Edna

# %%
# Using shape function 2
for index in range(brics.shape[0]):
    print('The Capital City of', brics.iloc[index, 0], 'is', brics.iloc[index, 3])
# Out:
# The Capital City of Brazil is Brasilia
# The Capital City of Russia is Moscow
# The Capital City of India is New Delhi
# The Capital City of China is Beijing
# The Capital City of South Africa is Pretoria
# The Capital City of Wakanda is Wakanda City
# The Capital City of Utopia is Edna

# %%
# Using shape function 3
for index, row in brics.iterrows():
    print("The Capital City of",row['country'],"is", row['capital'])
# Out:
# The Capital City of Brazil is Brasilia
# The Capital City of Russia is Moscow
# The Capital City of India is New Delhi
# The Capital City of China is Beijing
# The Capital City of South Africa is Pretoria
# The Capital City of Wakanda is Wakanda City
# The Capital City of Utopia is Edna

# %% [markdown]
# ## 2. CARS Dataset

# %%
# Print top 5 rows from the data, without any sorting or filter.
cars.head()
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True

# %%
## Print top 7 rows from the data
cars.head(7)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
## Print bottom rows
cars.tail()
# Out:
#   Unnamed: 0  cars_per_cap  country  drives_right
# 2        JAP           588    Japan         False
# 3         IN            18    India         False
# 4         RU           200   Russia          True
# 5        MOR            70  Morocco          True
# 6         EG            45    Egypt          True

# %%
## Print last 10 rows from the dataframe
cars.tail(10)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# Giving a name to the unnamed column

print(cars)

df1 = cars.rename( columns={'Unnamed: 0':'code'}, inplace=False ) 
cars.rename( columns={'Unnamed: 0':'code'}, inplace=True ) 

print(df1)
print(cars)      # With False, there will be no change in cars dataframe.
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True

# %%
## Print and Column Name
print(cars['cars_per_cap'])  # without column name at the top. Prints data and detail
# Out:
# 0    809
# 1    731
# 2    588
# 3     18
# 4    200
# 5     70
# 6     45
# Name: cars_per_cap, dtype: int64

# %%
## Print and Column Name 2
print(cars[['cars_per_cap']])  # print the actual data
# Out:
#    cars_per_cap
# 0           809
# 1           731
# 2           588
# 3            18
# 4           200
# 5            70
# 6            45

# %%
## Read the data again and set the 1st column as the index column. Then, print the cars dataframe.
cars = pd.read_csv('D:\\Amit\\AINE\\project6\\data\\cars.csv',index_col=0)

# %%
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
## Print the details of RU
cars.loc['RU']
# Out:
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object

# %%
## Can you change the above answer to show the column name at the top? 
cars.loc[['RU']]
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True

# %%
## Print all details for RU and AUS from cars dataframe.
cars.loc[['RU','AUS']]
# Out:
#      cars_per_cap    country  drives_right
# RU            200     Russia          True
# AUS           731  Australia         False

# %%
# Print the Cars Per Capita (cars_per_cap) for India (IN).
cars.loc[['IN']][['cars_per_cap']]
# Out:
#     cars_per_cap
# IN            18

# %%
# Print the Cars Per Capita (cars_per_cap) for India (IN) and Russia (RU).
cars.loc[['IN','RU']][['cars_per_cap']]
# Out:
#     cars_per_cap
# IN            18
# RU           200

# %%
# Print the Cars Per Capita and Country name for India and Russia
cars.loc[['IN','RU']][['cars_per_cap','country']]
# Out:
#     cars_per_cap country
# IN            18   India
# RU           200  Russia

# %% [markdown]
# ## 3. MARKS Dataset

# %%
## marks dataset was already imported
## Show the shape of the dataframe
marks.shape
# Out:
# (20, 7)

# %%
## Get the information and structure of the data with non-null value counts
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      20 non-null     object
#  1   Student_Name    20 non-null     object
#  2   English         20 non-null     float64
#  3   Maths           20 non-null     float64
#  4   Science         20 non-null     float64
#  5   History         20 non-null     float64
#  6   Social_Studies  20 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.2+ KB

# %%
#Print datatypes of the each column
marks.dtypes
# Out:
# Student_ID         object
# Student_Name       object
# English           float64
# Maths             float64
# Science           float64
# History           float64
# Social_Studies    float64
# dtype: object

# %%
## Understand various data-types
print(type(marks))
print(type(marks.English))  # Column's dtype is Series, the dtype of the values is Object.
print(type(5))
print(type(5.5))
print(type("Python"))
print(type(True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
## display() v/s print()
print(marks)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
display(marks)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
marks
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
# selecting marks for 'Ria'
display(marks.loc[(marks.Student_Name == 'Ria')])
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 17        S18          Ria  30.830802  25.545682  84.27165  78.727155
#
#     Social_Studies
# 17         7.30567

# %%
## Print all records for David
marks.loc[(marks['Student_Name']=='David')]
# Out:
#   Student_ID Student_Name    English      Maths    Science    History  \
# 3        S04        David  21.160844  95.052971  35.860852  62.865185
#
#    Social_Studies
# 3       95.264572

# %%
## Print all records is the Student IS is either S05 or S10
marks.loc[(marks['Student_ID']=='S05') | (marks['Student_ID']=='S10')]
# Out:
#   Student_ID Student_Name    English      Maths   Science    History  \
# 4        S05       Edward  63.250994  60.693247  7.020915  60.505272
# 9        S10         John  30.968731  14.282925  3.312853  79.916094
#
#    Social_Studies
# 4       34.041671
# 9       32.706891

# %%
## Fetch all details where marks in English > 70 or marks in Maths > 70.
marks.loc[(marks['English']>70) | (marks['Maths']>70)]
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 3        95.264572
# 5        85.019761
# 8        90.483635
# 11       71.930382
# 13       20.583259
# 15       74.528425
# 16        8.432155
# 18       83.344403

# %%
## Fetch all details where marks in English > 70 AND marks in Maths > 70
marks.loc[(marks['English']>70) & (marks['Maths']>70)]
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 18        S19        Suvin  72.218179  85.284128  32.55506  47.007177
#
#     Social_Studies
# 18       83.344403

# %%
## Fetch all details for all students except for Ria or the all students who are not Ria.
marks.loc[(marks['Student_Name'] != 'Ria')]
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 18       83.344403
# 19       82.802787

# %%
# Index column can be changed by giving the name of the column - unique and case-sensitive
marks = pd.read_csv('D:\\Amit\\AINE\\project6\\data\\marks.csv', index_col='Student_ID')  # could have given the index no. of the columns (0,1..) as well.
display(marks)
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# S14                Noel  72.833673   7.160086  22.089014  52.867757
# S15              Oliver   5.982402  16.460926  40.977224  80.925749
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891
# S11              34.449110
# S12              71.930382
# S13              80.665074
# S14              20.583259
# S15              83.312063
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
## Using LOC
display(marks.loc[['S20']])
# Out:
#            Student_Name    English      Maths   Science    History  \
# Student_ID
# S20                 Tan  18.070264  56.662635  2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S20              82.802787

# %%
## Using ILOC
display(marks.iloc[0:10])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891

# %%
#display(marks.iloc[S04])
# ILOC only takes Integer values

# %%
display(marks.loc[['S04']])
#LOC takes Label values
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S04               David  21.160844  95.052971  35.860852  62.865185
#
#             Social_Studies
# Student_ID
# S04              95.264572

# %%
# Selecting details of the 1st and 5th row
display(marks.iloc[[0, 4]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671

# %%
## Print the details from 0th, 5th and 8th rows, along with the details of indices 4th, 11th and 16th.
marks.iloc[[-1,4,7,4,11,16]]
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
#
#             Social_Studies
# Student_ID
# S20              82.802787
# S05              34.041671
# S08              74.530018
# S05              34.041671
# S12              71.930382
# S17               8.432155

# %%
display(marks.loc['S01':'S05'])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[2:5])
# Prints all values from all columns for indices 2 to 4, index 5 is not included.
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[0:5])
# Prints all values from all columns for indices 0 to 4, index 5 not included
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[:5])
## Displays all indices from start to 4(5-1)
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[15:20])
## Displays indices from 15 to 19
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[15:])
#Displays all rows starting from Index 15 to last index
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[15:100])
#Displays all rows starting from Index 15 to 99, but we know that last index is 19 in our Dataset
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[:])
## Displays all rows in Dataset as no specific value is chosen
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# S14                Noel  72.833673   7.160086  22.089014  52.867757
# S15              Oliver   5.982402  16.460926  40.977224  80.925749
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891
# S11              34.449110
# S12              71.930382
# S13              80.665074
# S14              20.583259
# S15              83.312063
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %% [markdown]
# ## 4. Temperature Dataset

# %%
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],  # With strings, it will become 'None'
          "temperature_f":[67.24,84.56,91.61,None,49.64]   #With numbers, it will become 'NaN'
         })
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
## Check for Null values
temps.isna()
# Out:
#    sequence  measurement_type  temperature_f
# 0     False             False          False
# 1     False             False          False
# 2     False             False          False
# 3     False              True           True
# 4     False             False          False

# %%
## Count of Null values from each column
temps.isna().sum()
# Out:
# sequence            0
# measurement_type    1
# temperature_f       1
# dtype: int64

# %%
## Count of all Null values from all columns
temps.isna().sum().sum()
# Out:
# 2

# %%
# Drop/delete the row containing missing values
clean_temps = temps.dropna(how='any')  # how: {'any', 'all'}. Default 'any'
display (clean_temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
## Copy paste the codes from the above cell, change the 'how' argument as 'all' and observe the difference in output.
clean_temps = temps.dropna(how='all')  # how: {'any', 'all'}. Default 'any'
display (clean_temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
temps.dropna()
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
# Drop the columns where at least one element is missing.
temps.dropna(axis = 'columns') # Without the 'axis' argument, rows will be dropped by default as you did in the previous code.
# Out:
#    sequence
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
temps['temperature_f'].cumsum()
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4    293.05
# Name: temperature_f, dtype: float64

# %%
# CAN YOU THINK OF ANY PRACTICAL USE OF cumsum() ?
# Cumulative Sum is useful to know the collections of observations below or above a certain value

# %%
temps['temperature_f'].cumsum(skipna=False)
## Including Null Value disturbs the calculation, and we don't get a true value.
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4       NaN
# Name: temperature_f, dtype: float64

# %%
# fill missing value with zero
temps.fillna(value=0, inplace = True)   # Do you remember the use of inplace? If not, please scroll up and check.
display(temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
# Why 0 in last column is 0.00 while only 0 in measurement_type? Please explain as a comment in this cell.
temps.dtypes
# Out:
# sequence              int64
# measurement_type     object
# temperature_f       float64
# dtype: object

# %% [markdown]
# #### The difference between 0 and 0.0 is because of the different data-type in both columns.

# %%
# fill missing value with previous value
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps.fillna(method='pad' , inplace=True)  # 'pad' means padding. Take value from previous row
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4           actual          91.61
# 4         5        estimated          49.64

# %%
# fill missing value with next value
temps1 = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps1.fillna(method='bfill' , inplace=True)  # bfill takes next value to replace
temps1
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4        estimated          49.64
# 4         5        estimated          49.64

# %%
# fill missing value with mean
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps['temperature_f'].fillna(temps['temperature_f'].mean(), inplace=True)  # Mean will not work on strings
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual        67.2400
# 1         2           actual        84.5600
# 2         3           actual        91.6100
# 3         4             None        73.2625
# 4         5        estimated        49.6400

# %% [markdown]
# ## Lambda Function

# %%
# Creating new dataframe to explore the use of Lambda and changing indices.

teams = pd.DataFrame({"Region":['North','West','East','South'],
          "Team":['One','Two','One','Two'],
          "Squad":['A','B','C','D'],
          "Revenue":[7500,5500,2750,6400],
            "Cost":[5200,5100,4400,5300]})

display (teams)
# Out:
#   Region Team Squad  Revenue  Cost
# 0  North  One     A     7500  5200
# 1   West  Two     B     5500  5100
# 2   East  One     C     2750  4400
# 3  South  Two     D     6400  5300

# %%
# apply() to alter values along an axis in your dataframe or in a series/column 

# Categorise based on the revenue and cost
teams['Profit'] = teams.apply(lambda x: 'Profit' if x['Revenue']>x['Cost'] else 'Loss',axis=1)
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit
# 0  North  One     A     7500  5200  Profit
# 1   West  Two     B     5500  5100  Profit
# 2   East  One     C     2750  4400    Loss
# 3  South  Two     D     6400  5300  Profit

# %%
# Use map() to substitute each value in a series
team_map = {"One":"Red","Two":"Blue"}      # new variable - dictionary (key-value pair)
teams['Team Color'] = teams['Team'].map(team_map) # A new column with mapped values
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
# applymap() method do elementwise operation on the entire dataframe.
# This method applies a function that accepts and returns a scalar to every element of a DataFrame.

teams.applymap(lambda x: len(str(x)))  # int(x) won't work because data has strings which can not be convereted to int.
# Out:
#    Region  Team  Squad  Revenue  Cost  Profit  Team Color
# 0       5     3      1        4     4       6           3
# 1       4     3      1        4     4       6           4
# 2       4     3      1        4     4       4           3
# 3       5     3      1        4     4       6           4

# %%
# Grouping on different categories. Needs the category as well as parameter
teams.groupby(['Profit']).max()
# Out:
#        Region Team Squad  Revenue  Cost Team Color
# Profit
# Loss     East  One     C     2750  4400        Red
# Profit   West  Two     D     7500  5300        Red

# %%
## Can you group the records on Cost with minimum values?
teams.groupby(['Cost']).min()
# Out:
#      Region Team Squad  Revenue  Profit Team Color
# Cost
# 4400   East  One     C     2750    Loss        Red
# 5100   West  Two     B     5500  Profit       Blue
# 5200  North  One     A     7500  Profit        Red
# 5300  South  Two     D     6400  Profit       Blue

# %%
## Can you group the records on Revenue column with mean values?
teams.groupby(['Revenue']).mean()
# Out:
#          Cost
# Revenue
# 2750     4400
# 5500     5100
# 6400     5300
# 7500     5200

# %%
# Grouping on the basis of aggregates
teams.groupby(['Team']).agg({'Revenue':['mean','min','max']})
# Out:
#      Revenue
#         mean   min   max
# Team
# One     5125  2750  7500
# Two     5950  5500  6400

# %% [markdown]
# ## Reset Index, Set Index and ReIndexing

# %%
# Setting two columns as index when a single column has not unique values.

teams_reindex = teams.set_index(['Region','Team'])  # 2 indices. useful when values are not unique
display(teams)

print()    # TO print blank/new line.


display(teams_reindex)
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue
#             Squad  Revenue  Cost  Profit Team Color
# Region Team
# North  One      A     7500  5200  Profit        Red
# West   Two      B     5500  5100  Profit       Blue
# East   One      C     2750  4400    Loss        Red
# South  Two      D     6400  5300  Profit       Blue

# %%
# Restructuring the dataframe based the multiple indices
stacked = pd.DataFrame(teams_reindex.stack())
stacked
# Out:
#                              0
# Region Team
# North  One  Squad            A
#             Revenue       7500
#             Cost          5200
#             Profit      Profit
#             Team Color     Red
# West   Two  Squad            B
#             Revenue       5500
#             Cost          5100
#             Profit      Profit
#             Team Color    Blue
# East   One  Squad            C
#             Revenue       2750
#             Cost          4400
#             Profit        Loss
#             Team Color     Red
# South  Two  Squad            D
#             Revenue       6400
#             Cost          5300
#             Profit      Profit
#             Team Color    Blue

# %% [markdown]
# ## Merging Dataframes

# %%
# Defining two new dataframes
group1 = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie', 'David'],
                    'number': [1, 2, 3, 4]})
group2 = pd.DataFrame({'name': ['Charlie', 'David', 'Edward', 'Ford'],
                    'number': [3, 4, 5, 6]})

# %%
group1
# Out:
#       name  number
# 0    Alice       1
# 1      Bob       2
# 2  Charlie       3
# 3    David       4

# %%
group2
# Out:
#       name  number
# 0  Charlie       3
# 1    David       4
# 2   Edward       5
# 3     Ford       6

# %%
group1.merge(group2,how='left', on='number')   # Left - all from 1st table and only common from 2nd table.

# Notice the NAN or empty values.
# Out:
#     name_x  number   name_y
# 0    Alice       1      NaN
# 1      Bob       2      NaN
# 2  Charlie       3  Charlie
# 3    David       4    David

# %%
group1.merge(group2)   # Shows only the common records.
# Out:
#       name  number
# 0  Charlie       3
# 1    David       4

# %%
group1.merge(group2,how='inner',left_on='number',right_on='number')  # Inner - Shows only the common records

# Why there are no null values now in the output? Answer as a comment.
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David

# %% [markdown]
# #### There are no Null values in output because the Merging is done based on common entries between Group1 and Group2 Dataframe.

# %% [markdown]
# ## Matplotlib and Seaborn Visualization in Python

# %%
## Check MTCARS Dataframe
mtcars.head()
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
## Reloading Data with 'car_names' as Index column
mtcars = pd.read_csv('D:\\Amit\\AINE\\project6\\data\\mtcars.csv',index_col='car_names')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# car_names
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# car_names
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
##Create a scatter plot with mpg and hp by providing xlabel and ylabel
fig = plt.figure(figsize=(6,3))
axes = fig.add_axes([0,0,1,1])
axes.set_xlabel('MPG')
axes.set_ylabel('HP')
axes.set_title('MPG v/s HP')
plt.scatter('mpg', 'hp', data=mtcars)
plt.show()

# %%
##Change the color to red in the previous code
fig = plt.figure(figsize=(6,3))
axes = fig.add_axes([0,0,1,1])
axes.set_xlabel('MPG')
axes.set_ylabel('HP')
axes.set_title('MPG v/s HP')
axes.scatter('mpg', 'hp', data=mtcars, color='red')
plt.show()

# %%
#Create crosstab for cyl(cylinder) and columns as count
# A cross-tabulation (or crosstab) is a two- (or more) dimensional table that records the number (frequency) of 
# respondents that have the specific characteristics described in the cells of the table.
pd.crosstab(mtcars['cyl'],mtcars['cyl'])
# Out:
# cyl   4  6   8
# cyl
# 4    11  0   0
# 6     0  7   0
# 8     0  0  14

# %%
#Alternate way to do crosstab
ct = pd.crosstab(mtcars.cyl, mtcars.cyl)
#ct.plot.bar(stacked=False)    # Try staked=False and then by removing stakced part
ct.plot.bar()
plt.legend(title='mark')   # Optional
plt.show()

# %%
## Create crosstab for cyl(cylinder) and am as 'ct2' and create a bar plot
ct2 = pd.crosstab(mtcars.cyl,mtcars.am)
ct2.plot.bar()
plt.legend(title='AM type')

# %%
## Create groupby (cyl) to visualize mpg and hp in a bar chart
# Hint: Use nunique()
cyl = mtcars.groupby('cyl')[['mpg','hp']].nunique()

# %%
cyl.plot(kind='bar')
plt.show()

# %%
#Create a pie chart for cyl count
plt.pie(x=mtcars['cyl'].unique(),labels=mtcars['cyl'].unique()) # + ':') + mtcars['cyl'].value_counts())
plt.legend()
plt.show()

# %%
## Alternate Pie-Chart
#Create a pie chart for cyl count
mtcars['cyl'].value_counts().plot(kind='pie',legend=True,autopct='%1.1f%%')
plt.show()
#Here Labels are cylinder-types

# %%
## Alternate Pie-Chart
#Create a pie chart for cyl count
mtcars['cyl'].value_counts().plot(kind='pie',labels=mtcars['cyl'].value_counts(),legend=True,autopct='%1.1f%%')
plt.show()
## Here Labels are cylinder-type counts

# %%
mtcars['cyl'].value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
mtcars['cyl'].unique()
# Out:
# array([6, 4, 8], dtype=int64)

# %%
## Create a Histogram for MPG column
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.hist('mpg', data=mtcars, bins=10)
axes.set_xlabel('MPG')
axes.set_ylabel('Count')
axes.set_title('MPG Distribution')
# Out:
# Text(0.5, 1.0, 'MPG Distribution')

# %%
## Alternate way to plot Histogram of a column in pandas
mtcars['mpg'].hist()

# %% [markdown]
# ## End of Notebook
